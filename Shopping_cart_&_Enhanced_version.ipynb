# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshDholaria/Python/blob/main/Shopping_cart_%26_Enhanced_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
products = []
prices = []
qyts = []

totalbill = 0
while True:

  print("Select the items you want to add in your cart:")
  print("1. Tomatos - $2.5")
  print("2. Onion - $4.0")
  print("3. Bellpepper -$3.25")
  print("4. Cucumber - $1.0")
  print("5. Brocollie - $4.5")
  print("0. To Bill")

  choice = int(input("Please select items to add: "))


  if choice == 1:
    price = 2.5
    product = "Tomatos"
  elif choice == 2:
    price = 4.0
    product = "Onion"
  elif choice == 3:
    price = 3.25
    product = "Bellpepper"
  elif choice == 4:
    price = 1.0
    product = "Cucumber"
  elif choice == 5:
    price = 4.5
    product = "Brocollie"
  elif choice == 0:
    break
  else:
    print("invalid choice")
    continue


  quantity = int(input("enetr QYT: "))
  iteamtotal = quantity*price
  totalbill = totalbill + iteamtotal

  products.append(product) ##helps to add items into the list
  qyts.append(quantity)
  prices.append(price)

  print("Iteam total: ",iteamtotal)

print("-----TOTAL BILL------")
for i in range(len(products)):
  print("Products: ", products[i], "\n Quntity: ", qyts[i], "\n Prices: $", prices[i])

print("Grand total: $", totalbill)
print("---------------------")
# Out:
# Select the items you want to add in your cart:
# 1. Tomatos - $2.5
# 2. Onion - $4.0
# 3. Bellpepper -$3.25
# 4. Cucumber - $1.0
# 5. Brocollie - $4.5
# 0. To Bill
# Please select items to add: 0
# -----TOTAL BILL------
# Grand total: $ 0
# ---------------------

# %%
## Updated version
products = []
prices = []
qyts = []

totalbill = 0

while True:
    print("\n Select Category")
    print("1. Groceries")
    print("2. Electronics")
    print("3. Packed Foods")
    print("0. To Bill")

    category = int(input("> "))

    if category == 0:
        break

    while True:

        if category == 1:
            print("\nGroceries")
            print("1. Tomato - $2.5")
            print("2. Onion - $4.0")
            print("3. Bellpepper - $3.25")
            print("4. Cucumber - $1.0")
            print("5. Brocollie - $4.5")
            print("0. Back")

        elif category == 2:
            print("\nElectronics")
            print("1. LG AC - $250")
            print("2. Ipad Pro - $400")
            print("3. LG TV - $325")
            print("4. LG Fridge - $100")
            print("5. Microwave - $45")
            print("0. Back")

        elif category == 3:
            print("\nPacked Foods")
            print("1. Tea 1kg pack- $2.5")
            print("2. Sugar 1kg pack- $4")
            print("3. Wheat Flour 10lb pack- $19.25")
            print("4. Milk 1L pack - $1.5")
            print("5. Baking Powder 100gm - $4.5")
            print("0. Back")

        else:
            print("Invalid Category")
            break

        choice = int(input("> "))

        if choice == 0:
            break

        if category == 1:
            if choice == 1:
                product = "Tomato"
                price = 2.5
            elif choice == 2:
                product = "Onion"
                price = 4.0
            elif choice == 3:
                product = "Bellpepper"
                price = 3.25
            elif choice == 4:
                product = "Cucumber"
                price = 1.0
            elif choice == 5:
                product = "Brocollie"
                price = 4.5
            else:
                print("Invalid choice")
                continue


        elif category == 2:
            if choice == 1:
                product = "LG AC"
                price = 250
            elif choice == 2:
                product = "Ipad Pro"
                price = 400
            elif choice == 3:
                product = "LG TV"
                price = 325
            elif choice == 4:
                product = "LG Fridge"
                price = 100
            elif choice == 5:
                product = "Microwave"
                price = 45
            else:
                print("Invalid choice")
                continue


        elif category == 3:
            if choice == 1:
                product = "Tea"
                price = 2.5
            elif choice == 2:
                product = "Sugar"
                price = 4
            elif choice == 3:
                product = "Wheat Flour"
                price = 3.25
            elif choice == 4:
                product = "Milk"
                price = 1
            elif choice == 5:
                product = "Baking Powder"
                price = 4.5
            else:
                print("Invalid choice")
                continue

        quantity = int(input("Enter Quantity: "))

        itemtotal = quantity * price

        products.append(product)
        qyts.append(quantity)
        prices.append(itemtotal)

        totalbill += itemtotal

        print("\nAdded to Cart!")


print("\n----- FINAL BILL -----")

for i in range(len(products)):
    print("\nProduct:", products[i])
    print("Quantity:", qyts[i])
    print("Price: $", prices[i])


print("\nGrand Total: $", totalbill)
print("----------------------")
# Out:
#  Select Category
# 1. Groceries
# 2. Electronics
# 3. Packed Foods
# 0. To Bill
# > 1
#
# Groceries
# 1. Tomato - $2.5
# 2. Onion - $4.0
# 3. Bellpepper - $3.25
# 4. Cucumber - $1.0
# 5. Brocollie - $4.5
# 0. Back
# > 1
# Enter Quantity: 2
#
# Added to Cart!
#
# Groceries
# 1. Tomato - $2.5
# 2. Onion - $4.0
# 3. Bellpepper - $3.25
# 4. Cucumber - $1.0
# 5. Brocollie - $4.5
# 0. Back
# > 9
# Invalid choice
#
# Groceries
# 1. Tomato - $2.5
# 2. Onion - $4.0
# 3. Bellpepper - $3.25
# 4. Cucumber - $1.0
# 5. Brocollie - $4.5
# 0. Back
# > 0
#
#  Select Category
# 1. Groceries
# 2. Electronics
# 3. Packed Foods
# 0. To Bill
# > 2
#
# Electronics
# 1. LG AC - $250
# 2. Ipad Pro - $400
# 3. LG TV - $325
# 4. LG Fridge - $100
# 5. Microwave - $45
# 0. Back
# > 3
# Enter Quantity: 1
#
# Added to Cart!
#
# Electronics
# 1. LG AC - $250
# 2. Ipad Pro - $400
# 3. LG TV - $325
# 4. LG Fridge - $100
# 5. Microwave - $45
# 0. Back
# > 0
#
#  Select Category
# 1. Groceries
# 2. Electronics
# ...
