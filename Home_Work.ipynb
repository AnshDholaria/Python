# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshDholaria/Python/blob/main/Home_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Positive, Negative, or Zero

num = float(input("please enter an number"))

if num > 0:
  print("positive number")
elif num == 0:
  print("zero")
else:
  print("negative number")
# Out:
# please enter an number0
# zero

# %%
#2 2. Even or Odd

num = float(input("please enter an number"))

if num % 2 == 0:
  print("even number")
else:
  print("odd number")
# Out:
# please enter an number23
# odd number

# %%
# 3. Largest of Two Numbers

num1 =  float(input("please enter no. 1 value"))
num2 =  float(input("please enter no. 2 value"))

if num1 > num2:
  print("NO1 is greater than No2")
elif num1 == num2:
  print("No1 is equal to No2")
else:
  print("No2 is greater than No1")
# Out:
# please enter no. 1 value12
# please enter no. 2 value23
# num2 is greater than num1

# %%
#4. Leap Year

num = int(input("please enter an year"))

if (num % 4) == 0:
  print("Leap Year")
else:
  print("NOT Leap Year")
# Out:
# please enter an year2028
# Leap Year

# %%
#5 Vowel or Consonant

character = input("please enter an character")

if character in ("aeiou"):
  print("Its a Vowel")
else:
  print("Its a Consonant")
# Out:
# please enter an charactere
# Its a Vowel

# %%
# 6. Largest of Three Numbers

num1 =  float(input("please enter no. 1 value"))
num2 =  float(input("please enter no. 2 value"))
num3 =  float(input("please enter no. 3 value"))

if num1 > num2 and num1 > num3:
  print("No 1 is grater than 2 & 3")
elif num2 > num1 and num2 > num3:
  print("No 2 is grater than 1 & 3")
elif num3 > num1 and num3 > num2:
  print("No 3 is grater than 1 & 2")
else:
  print("all equal")
# Out:
# please enter no. 1 value1
# please enter no. 2 value2
# please enter no. 3 value3
# No 3 is grater than 1 & 2

# %%
# 7. Divisible by Both 3 or 5

num = int(input("please enter an no"))

if (num % 3) == 0 and (num % 5) == 0:
  print("Divisible by both 3 and  5")
else:
  print("NOT Divisible by both 3 and 5")
# Out:
# please enter an no15
# Divisible by both 3  5

# %%
# 8. Triangle Type

side1 = float(input("enetr side 1"))
side2 = float(input("enetr side 2"))
side3 = float(input("enetr side 3"))

if side1 == side2 == side3:
  print("Its an equilateral triangle")
elif side1 == side2 or side1 == side3 or side2 == side3:
  print(" its an isosceles triangle")
else:
  print("its a scalene triangle")
# Out:
# enetr side 11
# enetr side 21
# enetr side 32
#  its an isosceles triangle

# %%
#9. Electricity Bill Category

units = int(input("please enter no. of units"))

if units <= 100:
  print("no charge")
elif units <= 200:
  print("charge is 5 per unit total:", units * 5)
elif units <= 300:
  print("charge is 10 per unit total:", units * 10)
elif units <= 400:
  print("charge is 15 per unit total:", units * 15)
else:
  print("charge is 20 per unit total:", units * 20)
# Out:
# please enter no. of units101
# charge is 5 per unit 505

# %%
#10. Simple Calculator

num1 =  float(input("please enter no. 1 value"))
num2 =  float(input("please enter no. 2 value"))
Caluclate = input("Add - 1, Sub - 2, Mul - 3, Div - 4")
if Caluclate == "1":
  print("Add:", num1 + num2)
elif Caluclate == "2":
  print("Sub:", num1 - num2)
elif Caluclate == "3":
  print("Mul:", num1 * num2)
elif Caluclate == "4":
  print("Div:", num1 / num2)
else:
  print("invalid input")
# Out:
# please enter no. 1 value4
# please enter no. 2 value4
# Add - 1, Sub - 2, Mul - 3, Div - 44
# Div: 1.0

# %%
# 11. Exam Eligibility

attend = int(input("no of days attented in %"))

if attend >= 75:
  print("Eligible for exam")
else:
  print("NOT Eligible for exam")
# Out:
# no of days attented in %70
# Not Eligible for exam

# %%
#12. Driving License Eligibility

age = int(input("enter age"))
sight = (input("Is eye sight good?, yes/no")).lower()

if age >= 18 and sight == "yes":
  print("eligible")
else:
  print("NOT eligible")
# Out:
# enter age21
# Is eye sight good?, yes/noyes
# eligible

# %%
#13. Bank Loan Eligibility

age = int(input("enter age"))
salary = int(input("enter salary"))
credit = int(input("enter crdit score"))
employed = input("enetr employment yes/no").lower()

if age >= 18 and salary >=50000 and credit >=650 and employed == "yes":
  print(" You are apporeved")
else:
  print("Try again later")
# Out:
# enter age12
# enter salary90000
# enter crdit score700
# enetr employment yes/noyes
# Try again later

# %%
# 14. Income Tax Calculator

salary = float(input("enter salary"))

if salary <= 10000:
  tax = salary * 0.10
elif salary <= 50000:
  tax = salary * 0.15
elif salary <= 100000:
  tax = salary * 0.25
else:
  tax = salary * 0.40
print("your tax is:", tax)
# Out:
# enter salary20000
# your tax is: 3000.0

# %%
#15. ATM Withdrawal Validation

balance = int(input("enetr the balance"))
Withdrawal = int(input("what amount you want to withdraw"))

if Withdrawal % 100 != 0:
  print("enetr multiple of 100")
elif Withdrawal > balance - 500:
  print("not sufficient balance")
else:
  print("your balance is", balance - Withdrawal)
# Out:
# enetr the balance500
# what amount you want to withdraw100
# not sufficient balance

# %%
#16. Shopping Discount Calculator

amount = int(input("enter amount"))
member = input("An member? yes/no").lower()

if member == "yes" and amount >=1000:
  discount = amount * 0.10
  print("your discount is:", discount)
elif member == "yes" and amount < 1000:
  discount = amount * 0.05
  print("your discount is:", discount)
else:
  print("became an member to get discount")
# Out:
# enter amount1000
# An member? yes/nono
# became an member to get discount

# %%
#17. Movie Ticket Pricing

age = int(input("enetr age"))
time = (input("day/night")).lower()
day = (input("weekend/weekday")).lower()

if age >=18:
  price = 10
else:
  price = 5

if time == "day":
  price = price + 1
elif time == "night":
  price = price + 2
else:
  print("invalid input")

if day == "weekend":
  price = price + 2
elif day == "weekday":
  price = price + 1
else:
  print("invalid input")

print("ticket price is", price)
# Out:
# enetr age19
# day/nightday
# weekend/weekdayweekday
# ticket price is 12

# %%
# 18. Employee Performance Evaluation

attendence = int(input("enter attendence %"))
project = int(input("enter no of project"))
rating = int(input("enter rating 1-5"))

if attendence >= 90 and project >= 5 and rating >= 4:
  print("excellent porfermance")
elif attendence >= 80 and project >= 3 and rating >= 3:
  print("good porfermance")
elif attendence >= 70 and project >= 2 and rating >= 2:
  print("fair porfermance")
else:
  print("poor porfermance")
# Out:
# enter attendence %75
# enter no of project3
# enter rating 1-52
# fair porfermance

# %%
# 19. College Admission Eligibility

grades = int(input("enetr gardes in 12: "))
entrance = int(input("grades in entrance exam "))

if grades >=70 and entrance >= 70:
  print("elegible for admission")
else:
  print("NOT eligible")
# Out:
# enetr gardes in 1220
# grades in entrance exam90
# NOT eligible

# %%
# 20. Insurance Premium Eligibility

age = int(input("enter age"))
vehicle = (input("enter type vehicle car/truck")).lower()
accidents = int(input("enter no of accidents"))
expereinced = input("experienced? yes/no").lower()

if age>= 21 and accidents <1  and expereinced == "yes":
  print("low permium")
elif accidents <= 2:
  print("Medium premium")
elif expereinced == "no":
  print("Medium premium")
elif vehicle == "truck":
  print("High premium")
else:
  print("High premium")
# Out:
# enter age25
# enter type vehicle car/trucktruck
# enter no of accidents2
# enter yes/nono
# Medium premium
